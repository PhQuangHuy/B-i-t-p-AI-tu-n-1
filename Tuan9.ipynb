# %% [markdown]
# <a href="https://colab.research.google.com/github/PhQuangHuy/B-i-t-p-AI-tu-n-1/blob/main/Tuan9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894086 sha256=8b0f72fdcf24c75367c5344c3c0db111863e624888b4f7c73dc8f16afb9a7b0f
#   Stored in directory: /root/.cache/pip/wheels/32/2c/a1/a90a7d7dd8448ec029f298a61f3490275e99b17aa348be675c
# Successfully built scikit-fuzzy
# ...

# %%
from keras.datasets import mnist
(train_images, test_images), (test_images, test_labels) = mnist.load_data()
import matplotlib.pyplot as plt
a=test_images[1234]
b=test_labels[1234]

# %%
from keras.datasets import mnist
(train_images, test_images), (test_images, train_labels) = mnist.load_data()
import matplotlib.pyplot as plt

hinh = train_images[100]
plt.imshow(hinh, cmap = plt.cm.binary)
plt.show
print('so này la', train_labels[100])
# Out:
# so này la 6

# %%
for i in range (10):
  plt.subplot(3,5,i+1)
  plt.tight_layout()
  plt.imshow(train_images[i],cmap='gray',interpolation = 'none')
  plt.title('So:{}'.format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras import models 
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(512,activation = 'relu',input_shape = (28*28,)))
model.add(Dense(10,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 512)               401920
#
#  dense_8 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images = train_images.reshape((60000,28*28))
train_images = train_images.astype('float32')/255
test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype('float32')/255

from keras.utils import to_categorical #One hot enceding 
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# %%
from keras.metrics import metrics
model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.fit(train_images, train_labels, epochs= 10, batch_size= 128)
test_loss,test_acc=model.evaluate(test_images,test_labels)
print('Hàm mất mát trong tệp kiểm tra (Test loss:)',test_loss)
print('Do chinh xac tren tap kiem tra :',test_acc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-fd509f60df2c> in <module>
#       1 from keras.metrics import metrics
#       2 model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# ----> 3 model.fit(train_images, train_labels, epochs= 10, batch_size= 128)
#       4 test_loss,test_acc=model.evaluate(test_images,test_labels)
#       5 print('Hàm mất mát trong tệp kiểm tra (Test loss:)',test_loss)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ...

# %%
model.save('model1.h5') #lưu lại
model11 = local_model('model1.h5')
model11.predict(test_images[51])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-4e46813f709b> in <module>
#       1 model.save('model1.h5') #lưu lại
# ----> 2 model11 = local_model('model1.h5')
#       3 model11.predict(test_images[51])
#
# NameError: name 'local_model' is not defined

# %%
from PIL import Image
from keras.utils import load_img
from numpy import asarray
from keras.utils import img_to_array
url = '/content/so7.png'
img = load_img(url)
plt.imshow(img)

# %%
img = a
print(img.size)
img = img_to_array(img)
print(img.size)
img = img.reshape(1,28*28)
img = img.astype('float32')
img = img/255
model.predict(img)
# Out:
# 784
# 784
# 1/1 [==============================] - 0s 381ms/step
# array([[0.07235067, 0.22097304, 0.05786175, 0.055543  , 0.04346183,
#         0.16411322, 0.05459479, 0.16538516, 0.1012805 , 0.06443605]],
#       dtype=float32)

# %%
plt.imshow(a)

# %%
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test)= cifar10.load_data()
import matplotlib.pyplot as plt
hinh = x_train[19]
plt.imshow(hinh, cmap =plt.cm.binary)
plt.show
print('hinh:', y_train[19])
# Out:
# ...
# 170498071/170498071 [==============================] - 12s 0us/step
# hinh: [6]

# %%
for i in range (10):
  plt.subplot(3,5,i+1)
  plt.tight_layout()
  plt.imshow(x_train[i],cmap='gray',interpolation = 'none')
  plt.title('So:{}'.format(y_train[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras import models 
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(512,activation = 'relu',input_shape = (28*28,)))
model.add(Dense(10,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 512)               401920
#
#  dense_10 (Dense)            (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape((60000,28*28))
x_images = x_train.astype('float32')/255
x_test = x_test.reshape((10000,28*28))
xtest = x_test.astype('float32')/255

from keras.utils import to_categorical #One hot enceding 
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-e4c8aa07e636> in <module>
# ----> 1 x_train = x_train.reshape((60000,28*28))
#       2 x_images = x_train.astype('float32')/255
#       3 x_test = x_test.reshape((10000,28*28))
#       4 xtest = x_test.astype('float32')/255
#       5
#
# ValueError: cannot reshape array of size 153600000 into shape (60000,784)
