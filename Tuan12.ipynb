# %% [markdown]
# <a href="https://colab.research.google.com/github/PhQuangHuy/B-i-t-p-AI-tu-n-1/blob/main/Tuan12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.1 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

filename ='/content/anhnhom.jpg'
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 4/4 [==============================] - 0s 42ms/step
# {'box': [565, 132, 41, 58], 'confidence': 0.9999988675117493, 'keypoints': {'left_eye': (574, 153), 'right_eye': (593, 155), 'nose': (582, 162), 'mouth_left': (572, 173), 'mouth_right': (591, 175)}}
# {'box': [219, 83, 34, 47], 'confidence': 0.9999982714653015, 'keypoints': {'left_eye': (230, 99), 'right_eye': (246, 102), 'nose': (238, 108), 'mouth_left': (228, 115), 'mouth_right': (242, 119)}}
# {'box': [491, 114, 38, 49], 'confidence': 0.999997079372406, 'keypoints': {'left_eye': (499, 131), 'right_eye': (517, 133), 'nose': (506, 136), 'mouth_left': (497, 148), 'mouth_right': (514, 150)}}
# {'box': [145, 231, 39, 47], 'confidence': 0.999992311000824, 'keypoints': {'left_eye': (155, 248), 'right_eye': (173, 248), 'nose': (163, 260), 'mouth_left': (155, 265), 'mouth_right': (173, 264)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/anhnhom.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x, y, width, height =face['box']
  rect = plt.Rectangle((x,y), width, height, fill=False, color = 'red')
  ax.add_patch(rect)
  plt.savefig('/content/drive/MyDrive/AnhScale')
plt.axis('off')
plt.show()
# Out:
# ...
# 4/4 [==============================] - 0s 42ms/step

# %%
from matplotlib.patches import Circle
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/deo-khau-trang.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x, y, width, height =face['box']
  rect = plt.Rectangle((x,y), width, height, fill=False, color = 'red')
  ax.add_patch(rect)
  for key, value in face['keypoints'].items():
    dot = plt.Circle(value, radius=2, color = 'red')
    ax.add_patch(d
    ax.add_patch(dot)

  plt.savefig('/content/drive/MyDrive/AnhScale')
plt.axis('off')
plt.show()
# Out:
# ...
# 3/3 [==============================] - 0s 26ms/step
